# %% [markdown]
# # Zenrows Scraping API EDA

# %% [markdown]
# ## Imports

# %%
import requests
from pprint import pprint
import polars
import json
import copy
import logging

# %% [markdown]
# ## Functions

# %%
def load_json_data(json_file_path):
    try:
        # Open and read the JSON file
        with open(json_file_path, 'r') as file:
            parsed_json_data = json.load(file)

        return parsed_json_data
    except UnicodeDecodeError as e: 
        logging.error(e)
        raise e
    except Exception as e:
        logging.error(e)
        raise e
    
valid_json_file_path = '../data/network_requests.json'
res = load_json_data(valid_json_file_path)
print(res)

# invalid_json_file_path = '../data/turo.com.har'
# res = load_json_data(invalid_json_file_path)
# print(res)
# Out:
# {'data_type': 'Turo Search Page Results', 'timestamp': '2024-10-13T23:48:54.662Z', 'entries': [{'request_method': 'POST', 'request_url': 'https://turo.com/api/v2/search', 'response_status': 200, 'response_status_text': '', 'response_content': {'banner': {'actionText': None, 'bannerDesign': {'animationLoopCount': None, 'animationURL': None, 'clickableURL': None, 'designVariant': None, 'resizeableIconDarkURL': 'https://resources.turo.com/resources/img/banner/thumbs-up-dark__H6f7aeec8335a018494e506131904a399__.jpg', 'resizeableIconURL': 'https://resources.turo.com/resources/img/banner/thumbs-up__H8e2ff43641228b6c6246c70974174b4a__.jpg', 'withBorder': True}, 'bannerName': 'CHECKOUT_MORE_THAN_25_HR', 'text': 'Donâ€™t stress: you can cancel your trip for free, up to 24 hours before it starts.', 'title': None}, 'dismissibleBanner': None, 'makesFilterCount': None, 'searchId': '9FyJbenr', 'searchLocation': {'appliedRadius': {'unit': 'MILES', 'value': 38.2182017975829}, 'country': 'US', 'isOperational': True, 'locationId': None, 'name': None, 'point': {'lat': 42.4378405, 'lng': -78.4751945}, 'shortName': None, 'topPois': [], 'type': 'POINT'}, 'totalHits': 56, 'vehicles': [{'availability': None, 'avgDailyPrice': {'amount': 61.2, 'currency': 'USD'}, 'completedTrips': 14, 'estimatedQuote': None, 'hostId': 42801905, 'id': 2706225, 'images': [{'originalImageUrl': 'https://images.turo.com/media/vehicle/images/Ve-3pJyESBKK7QKKW-O3Og.jpg', 'resizeableUrlTemplate': 'https://images.turo.com/media/vehicle/images/Ve-3pJyESBKK7QKKW-O3Og.{width}x{height}.jpg'}], 'isAllStarHost': False, 'isFavoritedBySearcher': False, 'isNewListing': False, 'location': {'city': 'Lackawanna', 'country': 'US', 'distance': {'unit': 'MILES', 'value': 32.07219451118512}, 'homeLocation': {'lat': 42.82337016041945, 'lng': -78.8265809482411}, 'isDelivery': False, 'locationId': None, 'locationSlugs': {'fr_CA': 'lackawanna-ny', 'en_GB': 'lackawanna-ny', 'en_CA': 'lackawanna-ny', 'en_US': 'lackawanna-ny', 'en_AU': 'lackawanna-ny', 'fr_FR': 'lackawanna-ny'}, 'state': 'NY'}, 'make': 'Ford', 'model': 'Explorer', 'rating': 4.9167, 'seoCategory': 'SUV', 'tags': [], 'type': 'SUV', 'year': 2021}, {'availability': None, 'avgDailyPrice': {'amount': 74.42, 'currency': 'USD'}, 'completedTrips': 4, 'estimatedQuote': None, 'hostId': 35773880, 'id': 2684821, 'images': [{'originalImageUrl': 'https://images.turo.com/media/vehicle/images/qr_u6oJoTLm6mORGKGu68A.jpg', 'resizeableUrlTemplate': 'https://images.turo.com/media/vehicle/images/qr_u6oJoTLm6mORGKGu68A.{width}x{height}.jpg'}], 'isAllStarHost': False, 'isFavoritedBySearcher': False, 'isNewListing': False, 'location': {'city': 'Cheektowaga', 'country': 'US', 'distance': {'unit': 'MILES', 'value': 33.32987895405703}, 'homeLocation': {'lat': 42.88234271065046, 'lng': -78.73002083192799}, 'isDelivery': False, 'locationId': None, 'locationSlugs': {'fr_CA': 'cheektowaga-ny', 'en_GB': 'cheektowaga-ny', 'en_CA': 'cheektowaga-ny', 'en_US': 'cheektowaga-ny', 'en_AU': 'cheektowaga-ny', 'fr_FR': 'cheektowaga-ny'}, 'state': 'NY'}, 'make': 'Jeep', 'model': 'Grand Cherokee', 'rating': 5, 'seoCategory': 'SUV', 'tags': [], 'type': 'SUV', 'year': 2021}, {'availability': None, 'avgDailyPrice': {'amount': 44.1, 'currency': 'USD'}, 'completedTrips': 41, 'estimatedQuote': None, 'hostId': 27203938, 'id': 2601609, 'images': [{'originalImageUrl': 'https://images.turo.com/media/vehicle/images/PkzIlrauSa-OOG1YX3UV6Q.jpg', 'resizeableUrlTemplate': 'https://images.turo.com/media/vehicle/images/PkzIlrauSa-OOG1YX3UV6Q.{width}x{height}.jpg'}], 'isAllStarHost': True, 'isFavoritedBySearcher': False, 'isNewListing': False, 'location': {'city': 'Depew', 'country': 'US', 'distance': {'unit': 'MILES', 'value': 35.89793804503363}, 'homeLocation': {'lat': 42.921227654117125, 'lng': -78.7342744380086}, 'isDelivery': False, 'locationId': None, 'locationSlugs': {'fr_CA': 'depew-ny', 'en_GB': 'depew-ny', 'en_CA': 'depew-ny', 'en_US': 'depew-ny', 'en_AU': 'depew-ny', 'fr_FR': 'depew-n ...

# %% [markdown]
# ## Test request

# %%
url = 'https://turo.com/api/vehicle/daily_pricing?end=10%2F12%2F2023&start=08%2F01%2F2022&vehicleId=1711107'
apikey = '43adce71ec56b763f7ab9e710da66c81c448013b'
params = {
    'url': url,
    'apikey': apikey,
}
response = requests.get('https://api.zenrows.com/v1/', params=params)
print(response.text)
# Out:
# {"calendarCurrencyHeader":"All prices are in CAD","dailyPricingResponses":[{"custom":false,"date":"2022-08-01","localizedDayOfWeek":"Monday","localizedShortDayOfWeek":"Mon","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-02","localizedDayOfWeek":"Tuesday","localizedShortDayOfWeek":"Tue","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-03","localizedDayOfWeek":"Wednesday","localizedShortDayOfWeek":"Wed","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-04","localizedDayOfWeek":"Thursday","localizedShortDayOfWeek":"Thu","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-05","localizedDayOfWeek":"Friday","localizedShortDayOfWeek":"Fri","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-06","localizedDayOfWeek":"Saturday","localizedShortDayOfWeek":"Sat","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-07","localizedDayOfWeek":"Sunday","localizedShortDayOfWeek":"Sun","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-08","localizedDayOfWeek":"Monday","localizedShortDayOfWeek":"Mon","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-09","localizedDayOfWeek":"Tuesday","localizedShortDayOfWeek":"Tue","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-10","localizedDayOfWeek":"Wednesday","localizedShortDayOfWeek":"Wed","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-11","localizedDayOfWeek":"Thursday","localizedShortDayOfWeek":"Thu","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-12","localizedDayOfWeek":"Friday","localizedShortDayOfWeek":"Fri","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-13","localizedDayOfWeek":"Saturday","localizedShortDayOfWeek":"Sat","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-14","localizedDayOfWeek":"Sunday","localizedShortDayOfWeek":"Sun","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-15","localizedDayOfWeek":"Monday","localizedShortDayOfWeek":"Mon","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-16","localizedDayOfWeek":"Tuesday","localizedShortDayOfWeek":"Tue","price":68.00,"priceEditable":true,"priceWithCurrency":{"amount":68.00,"currencyCode":"CAD"},"source":"DEFAULT","wholeDayUnavailable":false},{"custom":false,"date":"2022-08-17","localizedDayOfWeek":"Wednesday","localizedShort ...

# %%
with open("../data/daily_pricing.json", "w") as fp:
    json.dump(response.json(),fp)
# pprint(response.json())

# %%
daily_prcing_responses = response.json()['dailyPricingResponses']

for idx in range(len(daily_prcing_responses)):
    _date = daily_prcing_responses[idx]['date']
    _price = daily_prcing_responses[idx]['price']
    _wholeDayUnavailable = daily_prcing_responses[idx]['wholeDayUnavailable']
    _source =  daily_prcing_responses[idx]['source']
    
    
    print(f"{idx} - On date {_date}, the price was set by {_source} at {_price} & the car was {'Booked' if _wholeDayUnavailable else 'Available'}")
# Out:
# 0 - On date 2022-08-01, the price was set by DEFAULT at 68.0 & the car was Available
# 1 - On date 2022-08-02, the price was set by DEFAULT at 68.0 & the car was Available
# 2 - On date 2022-08-03, the price was set by DEFAULT at 68.0 & the car was Available
# 3 - On date 2022-08-04, the price was set by DEFAULT at 68.0 & the car was Available
# 4 - On date 2022-08-05, the price was set by DEFAULT at 68.0 & the car was Available
# 5 - On date 2022-08-06, the price was set by DEFAULT at 68.0 & the car was Available
# 6 - On date 2022-08-07, the price was set by DEFAULT at 68.0 & the car was Available
# 7 - On date 2022-08-08, the price was set by DEFAULT at 68.0 & the car was Available
# 8 - On date 2022-08-09, the price was set by DEFAULT at 68.0 & the car was Available
# 9 - On date 2022-08-10, the price was set by DEFAULT at 68.0 & the car was Available
# 10 - On date 2022-08-11, the price was set by DEFAULT at 68.0 & the car was Available
# 11 - On date 2022-08-12, the price was set by DEFAULT at 68.0 & the car was Available
# 12 - On date 2022-08-13, the price was set by DEFAULT at 68.0 & the car was Available
# 13 - On date 2022-08-14, the price was set by DEFAULT at 68.0 & the car was Available
# 14 - On date 2022-08-15, the price was set by DEFAULT at 68.0 & the car was Available
# 15 - On date 2022-08-16, the price was set by DEFAULT at 68.0 & the car was Available
# 16 - On date 2022-08-17, the price was set by DEFAULT at 68.0 & the car was Available
# 17 - On date 2022-08-18, the price was set by DEFAULT at 68.0 & the car was Available
# 18 - On date 2022-08-19, the price was set by DEFAULT at 68.0 & the car was Available
# 19 - On date 2022-08-20, the price was set by DEFAULT at 68.0 & the car was Available
# 20 - On date 2022-08-21, the price was set by DEFAULT at 68.0 & the car was Available
# 21 - On date 2022-08-22, the price was set by DEFAULT at 68.0 & the car was Available
# 22 - On date 2022-08-23, the price was set by DEFAULT at 68.0 & the car was Available
# 23 - On date 2022-08-24, the price was set by DEFAULT at 68.0 & the car was Available
# 24 - On date 2022-08-25, the price was set by DEFAULT at 68.0 & the car was Available
# 25 - On date 2022-08-26, the price was set by DEFAULT at 68.0 & the car was Available
# 26 - On date 2022-08-27, the price was set by DEFAULT at 68.0 & the car was Available
# 27 - On date 2022-08-28, the price was set by DEFAULT at 68.0 & the car was Available
# 28 - On date 2022-08-29, the price was set by DEFAULT at 68.0 & the car was Available
# 29 - On date 2022-08-30, the price was set by DEFAULT at 68.0 & the car was Available
# 30 - On date 2022-08-31, the price was set by DEFAULT at 68.0 & the car was Available
# 31 - On date 2022-09-01, the price was set by DEFAULT at 68.0 & the car was Available
# 32 - On date 2022-09-02, the price was set by DEFAULT at 68.0 & the car was Available
# 33 - On date 2022-09-03, the price was set by DEFAULT at 68.0 & the car was Available
# 34 - On date 2022-09-04, the price was set by DEFAULT at 68.0 & the car was Available
# 35 - On date 2022-09-05, the price was set by DEFAULT at 68.0 & the car was Available
# 36 - On date 2022-09-06, the price was set by DEFAULT at 68.0 & the car was Available
# 37 - On date 2022-09-07, the price was set by DEFAULT at 68.0 & the car was Available
# 38 - On date 2022-09-08, the price was set by DEFAULT at 68.0 & the car was Available
# 39 - On date 2022-09-09, the price was set by DEFAULT at 68.0 & the car was Available
# 40 - On date 2022-09-10, the price was set by DEFAULT at 68.0 & the car was Available
# 41 - On date 2022-09-11, the price was set by DEFAULT at 68.0 & the car was Available
# 42 - On date 2022-09-12, the price was set by DEFAULT at 68.0 & the car was Available
# 43 - On date 2022-09-13, the price was set by DEFAULT at 68.0 & the car was Available
# 44 - On date 2022-09-14, the price was set by DEFAULT at 68.0 & the car was Available
# 45 - On date 2022-09-15, the price was set by DEFAULT at 68.0 & the car was Available
# 46 - On date 2022-09-16, the price was set by DEFAULT at 68.0 & the car was Available
# 47 - On date 2022-09-17, the price was set by DEFAULT at 68.0 & the car was Available
# 48 - On date 2022-09-18, the price was set by DEFAULT at 68.0 & the car was Available
# 49 - On date 2022-09-19, the price was set by DEFAULT at 68.0 & the car was Available
# 50 - On date 2022-09-20, the price was set by DEFAULT at 68.0 & the car was Available
# 51 - On date 2022-09-21, the price was set by DEFAULT at 68.0 & the car was Available
# 52 - On date 2022-09-22, the price was set by DEFAULT at 68.0 & the car was Available
# 53 - On date 2022-09-23, the price was set by DEFAULT at 68.0 & the car was Available
# 54 - On date 2022-09-24, the price was set by DEFAULT at 68.0 & the car was Available
# 55 - On date 2022-09-25, the price was set by DEFAULT at 68.0 & the car was Available
# 56 - On date 2022-09-26, the price was set by DEFAULT at 68.0 & the car was Available
# 57 - On date 2022-09-27, the price was set by DEFAULT at 68.0 & the car was Available
# 58 - On date 2022-09-28, the price was set by DEFAULT at 68.0 & the car was Available
# 59 - On date 2022-09-29, the price was set by DEFAULT at 68.0 & the car was Available
# 60 - On date 2022-09-30, the price was set by DEFAULT at 68.0 & the car was Available
# 61 - On date 2022-10-01, the price was set by DEFAULT at 68.0 & the car was Available
# 62 - On date 2022-10-02, the price was set by DEFAULT at 68.0 & the car was Available
# 63 - On date 2022-10-03, the price was set by DEFAULT at 68.0 & the car was Available
# 64 - On date 2022-10-04, the price was set by DEFAULT at 68.0 & the car was Available
# 65 - On date 2022-10-05, the price was set by DEFAULT at 68.0 & the car was Available
# 66 - On date 2022-10-06, the price was set by DEFAULT at 68.0 & the car was Available
# 67 - On date 2022-10-07, the price was set by DEFAULT at 68.0 & the car was Available
# 68 - On date 2022-10-08, the price was set by DEFAULT at 68.0 & the car was Booked
# 69 - On date 2022-10-09, the price was set by DEFAULT at 68.0 & the car was Available
# 70 - On date 2022-10-10, the price was set by DEFAULT at 68.0 & the car was Available
# 404 - On date 2023-09-09, the price was set by OWNER at 86.0 & the car was Booked
# 405 - On date 2023-09-10, the price was set by OWNER at 86.0 & the car was Available
# 406 - On date 2023-09-11, the price was set by OWNER at 70.0 & the car was Available
# 407 - On date 2023-09-12, the price was set by OWNER at 65.0 & the car was Available
# 408 - On date 2023-09-13, the price was set by OWNER at 65.0 & the car was Available
# 409 - On date 2023-09-14, the price was set by OWNER at 73.0 & the car was Available
# 410 - On date 2023-09-15, the price was set by OWNER at 73.0 & the car was Booked
# 411 - On date 2023-09-16, the price was set by OWNER at 73.0 & the car was Booked
# 412 - On date 2023-09-17, the price was set by OWNER at 73.0 & the car was Booked
# 413 - On date 2023-09-18, the price was set by OWNER at 73.0 & the car was Booked
# 414 - On date 2023-09-19, the price was set by OWNER at 73.0 & the car was Booked
# 415 - On date 2023-09-20, the price was set by OWNER at 73.0 & the car was Booked
# 416 - On date 2023-09-21, the price was set by OWNER at 100.0 & the car was Available
# 417 - On date 2023-09-22, the price was set by OWNER at 70.0 & the car was Available
# 418 - On date 2023-09-23, the price was set by OWNER at 90.0 & the car was Available
# 419 - On date 2023-09-24, the price was set by OWNER at 90.0 & the car was Available
# 420 - On date 2023-09-25, the price was set by OWNER at 355.0 & the car was Available
# 421 - On date 2023-09-26, the price was set by OWNER at 355.0 & the car was Available
# 422 - On date 2023-09-27, the price was set by OWNER at 355.0 & the car was Available
# 423 - On date 2023-09-28, the price was set by OWNER at 200.0 & the car was Available
# 424 - On date 2023-09-29, the price was set by OWNER at 70.0 & the car was Available
# 425 - On date 2023-09-30, the price was set by OWNER at 70.0 & the car was Booked
# 426 - On date 2023-10-01, the price was set by OWNER at 70.0 & the car was Available
# 427 - On date 2023-10-02, the price was set by OWNER at 75.0 & the car was Available
# 428 - On date 2023-10-03, the price was set by OWNER at 75.0 & the car was Available
# 429 - On date 2023-10-04, the price was set by OWNER at 68.0 & the car was Available
# 430 - On date 2023-10-05, the price was set by OWNER at 100.0 & the car was Available
# 431 - On date 2023-10-06, the price was set by OWNER at 75.0 & the car was Available
# 432 - On date 2023-10-07, the price was set by OWNER at 75.0 & the car was Booked
# 433 - On date 2023-10-08, the price was set by OWNER at 75.0 & the car was Booked
# 434 - On date 2023-10-09, the price was set by OWNER at 75.0 & the car was Booked
# 435 - On date 2023-10-10, the price was set by OWNER at 68.0 & the car was Available
# 436 - On date 2023-10-11, the price was set by OWNER at 65.0 & the car was Available
# 437 - On date 2023-10-12, the price was set by OWNER at 65.0 & the car was Available

# %% [markdown]
# ## Parse Turo search page results

# %% [markdown]
# ### Load JSON data from a turo search page scraping

# %%
# Specify the path to your JSON file
json_file_path = '../data/network_requests.json'

# Open and read the JSON file
with open(json_file_path, 'r') as file:
    turo_search_data = json.load(file)

# %%
turo_vehicle_search_item = turo_search_data['entries'][0]['response_content']['vehicles'][0]
pprint(turo_vehicle_search_item)
# Out:
# {'availability': None,
#  'avgDailyPrice': {'amount': 61.2, 'currency': 'USD'},
#  'completedTrips': 14,
#  'estimatedQuote': None,
#  'hostId': 42801905,
#  'id': 2706225,
#  'images': [{'originalImageUrl': 'https://images.turo.com/media/vehicle/images/Ve-3pJyESBKK7QKKW-O3Og.jpg',
#              'resizeableUrlTemplate': 'https://images.turo.com/media/vehicle/images/Ve-3pJyESBKK7QKKW-O3Og.{width}x{height}.jpg'}],
#  'isAllStarHost': False,
#  'isFavoritedBySearcher': False,
#  'isNewListing': False,
#  'location': {'city': 'Lackawanna',
#               'country': 'US',
#               'distance': {'unit': 'MILES', 'value': 32.07219451118512},
#               'homeLocation': {'lat': 42.82337016041945,
#                                'lng': -78.8265809482411},
#               'isDelivery': False,
#               'locationId': None,
#               'locationSlugs': {'en_AU': 'lackawanna-ny',
#                                 'en_CA': 'lackawanna-ny',
#                                 'en_GB': 'lackawanna-ny',
#                                 'en_US': 'lackawanna-ny',
#                                 'fr_CA': 'lackawanna-ny',
#                                 'fr_FR': 'lackawanna-ny'},
#               'state': 'NY'},
#  'make': 'Ford',
#  'model': 'Explorer',
#  'rating': 4.9167,
#  'seoCategory': 'SUV',
#  'tags': [],
#  'type': 'SUV',
#  'year': 2021}

# %% [markdown]
# ### Import Pydantic model

# %%
## imported model from ../etl/model/search_page_models.py

from typing import Any, List, Optional
from pydantic import BaseModel, ValidationError


class AvgDailyPrice(BaseModel):
    amount: float
    currency: str


class Image(BaseModel):
    originalImageUrl: str
    resizeableUrlTemplate: str


class Distance(BaseModel):
    unit: str
    value: float


class HomeLocation(BaseModel):
    lat: float
    lng: float


class LocationSlugs(BaseModel):
    fr_CA: str
    en_GB: str
    en_CA: str
    en_US: str
    en_AU: str
    fr_FR: str


class Location(BaseModel):
    city: str
    country: str
    distance: Distance
    homeLocation: HomeLocation
    isDelivery: bool
    locationId: Optional[Any]  # Adjust type if more information is available
    locationSlugs: LocationSlugs
    state: str


class Tag(BaseModel):
    label: str
    type: str


class VehicleSearchModel(BaseModel):
    availability: Optional[Any]  # Adjust type if more information is available
    avgDailyPrice: AvgDailyPrice
    completedTrips: int
    estimatedQuote: Optional[Any]  # Adjust type if more information is available
    hostId: int
    id: int
    images: List[Image]
    isAllStarHost: bool
    isFavoritedBySearcher: bool
    isNewListing: bool
    location: Location
    make: str
    model: str
    rating: float
    seoCategory: str
    tags: List[Tag]
    type: str
    year: int

# %% [markdown]
# ### Parse data using pydantic

# %%
try:
    parsed_data = VehicleSearchModel(**turo_vehicle_search_item)
    pprint(parsed_data)
except ValidationError as e:
    print(f"Validation error: {e}")
# Out:
# VehicleSearchModel(availability=None, avgDailyPrice=AvgDailyPrice(amount=61.2, currency='USD'), completedTrips=14, estimatedQuote=None, hostId=42801905, id=2706225, images=[Image(originalImageUrl='https://images.turo.com/media/vehicle/images/Ve-3pJyESBKK7QKKW-O3Og.jpg', resizeableUrlTemplate='https://images.turo.com/media/vehicle/images/Ve-3pJyESBKK7QKKW-O3Og.{width}x{height}.jpg')], isAllStarHost=False, isFavoritedBySearcher=False, isNewListing=False, location=Location(city='Lackawanna', country='US', distance=Distance(unit='MILES', value=32.07219451118512), homeLocation=HomeLocation(lat=42.82337016041945, lng=-78.8265809482411), isDelivery=False, locationId=None, locationSlugs=LocationSlugs(fr_CA='lackawanna-ny', en_GB='lackawanna-ny', en_CA='lackawanna-ny', en_US='lackawanna-ny', en_AU='lackawanna-ny', fr_FR='lackawanna-ny'), state='NY'), make='Ford', model='Explorer', rating=4.9167, seoCategory='SUV', tags=[], type='SUV', year=2021)

# %%
## mess up the data and see the validation error
turo_vehicle_search_item_invalid = copy.copy(turo_vehicle_search_item)
turo_vehicle_search_item_invalid['avgDailyPrice']='20'
try:
    parsed_data = VehicleSearchModel(**turo_vehicle_search_item_invalid)
    pprint(parsed_data)
except ValidationError as e:
    print(f"Validation error: {e}")
# Out:
# Validation error: 1 validation error for VehicleSearchModel
# avgDailyPrice
#   Input should be a valid dictionary or instance of AvgDailyPrice [type=model_type, input_value='20', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/model_type

# %% [markdown]
# ## Automting extraction flow for daily_pricing

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('../data/turo.sqlite')

# Create a cursor object using the cursor() method
cursor = conn.cursor()

print("Connected to the database successfully")
# Out:
# Connected to the database successfully

# %%
query = """
SELECT v.id,
    v.listing_created_date,
    v.listing_active
FROM vehicles as v
WHERE listing_created_date is NULL;
"""

cursor.execute(query)
results = cursor.fetchall()

# Convert the results to a Polars DataFrame
df = polars.DataFrame(results, schema=["id", "listing_created_date", "listing_active"])

# Print the DataFrame
df.head()
# Out:
# C:\Users\43e4eeee\AppData\Local\Temp\ipykernel_19784\199854158.py:13: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   df = polars.DataFrame(results, schema=["id", "listing_created_date", "listing_active"])
# shape: (5, 3)
# ┌─────────┬──────────────────────┬────────────────┐
# │ id      ┆ listing_created_date ┆ listing_active │
# │ ---     ┆ ---                  ┆ ---            │
# │ i64     ┆ null                 ┆ null           │
# ╞═════════╪══════════════════════╪════════════════╡
# │ 514340  ┆ null                 ┆ null           │
# │ 597559  ┆ null                 ┆ null           │
# │ 1109057 ┆ null                 ┆ null           │
# │ 1120970 ┆ null                 ┆ null           │
# │ 1159994 ┆ null                 ┆ null           │
# └─────────┴──────────────────────┴────────────────┘

# %%
vehicleId = 514340
url = f'https://turo.com/api/vehicle/detail?vehicleId={vehicleId}'
apikey = '43adce71ec56b763f7ab9e710da66c81c448013b'
params = {
    'url': url,
    'apikey': apikey,
}
response = requests.get('https://api.zenrows.com/v1/', params=params)
# Out:
# {"airportLocations":[],"badges":[{"id":5,"label":"AUX input","value":"aux_input"},{"id":27,"label":"Backup camera","value":"backup_camera"},{"id":17,"label":"Bluetooth","value":"bluetooth"},{"id":4,"label":"GPS","value":"gps"},{"id":23,"label":"Heated seats","value":"heated_seats"},{"id":16,"label":"Long-term car","value":"long_term_rental"},{"id":22,"label":"Snow tires or chains","value":"snow_tires"},{"id":24,"label":"Sunroof","value":"sunroof"},{"id":21,"label":"Toll pass","value":"toll_pass"},{"id":30,"label":"USB charger","value":"usb_charger"},{"id":20,"label":"USB input","value":"usb_input"}],"basicCarDetails":{"averageFuelEconomy":null,"averageFuelEconomyWithLabel":null,"cityFuelEconomy":null,"fuelGrade":null,"fuelType":{"label":"Electric","value":"ELECTRIC"},"fuelTypeAndGradeLabel":"Electric","fuelUnit":"LITERS_PER_100_KILOMETERS","fuelUnitLabel":"L/100km","highwayFuelEconomy":null,"numberOfDoors":2,"numberOfDoorsLabel":"2 doors","numberOfSeats":2,"numberOfSeatsLabel":"2 seats"},"color":"BLACK","currentVehicleProtection":{"companyInfo":null,"deliveryOwnerFraction":0.750000,"displayName":"75 plan","hostDeliveryTakeRate":0.90,"hostTakeRate":0.750000,"insurance":null,"insuranceLicenseNumber":null,"insuranceProviderCaption":null,"insuranceProviderDescription":"Insurance via Economical","insuranceProviderDisplayName":"Economical","insuranceProviderTitle":"Insurance & Protection","label":"75 plan","location":null,"vehicleProtectionLevel":"SEVENTYFIVEPLAN_CA_2023","website":null},"dateRangeRate":null,"description":"**** City car, especially for the winter, only around 60km of range, need to feel comfortable with the charging network***\n\n\uD83D\uDD0C⚡️\uD83D\uDD0B\nWow! Great looking ELECTRIC Smart with 100-130km range depending how you drive it (A little less in the winter ~50 to 70km), charges to full capacity in around 2.5 hours with 240volts or 13 hours on a regular 120volt plug (Included with the Car). It's loaded with NAVI, Bluetooth, heated seats ANDDDD FREE A25 passages and 0$ on gas!!  And this car is actually pretty fun to drive too!\n\n(Plugging the Car is very simple and straightforward - when you plug the car you need to feel a “clip”, if you don’t feel comfortable or capable of plugging it in properly or dealing with Range, please do not rent this car as it will not charge if not properly plugged)\n\n****DOWNLOAD THE CircuitElectrique APP ON YOUR PHONE AND SIGN UP TO GAIN ACCESS TO THE ÉLECTRIQUE CIRCUIT ALL OVER MONTREAL AND QUEBEC, you will need a phone with internet to unlock the charging stations****\n\nCar will have 100% battery when you come pick it up !","extras":{"extras":[{"description":"","enabled":true,"extraId":97776,"extraPricingType":"PER_TRIP","extraType":{"category":{"label":"Convenience","value":"CONVENIENCE"},"label":"Prepaid EV recharge","maxQuantity":1,"priceRecommendationSummary":null,"suggestedDescription":null,"value":"PREPAID_EV_RECHARGE"},"priceWithCurrency":{"amount":3.00,"currencyCode":"CAD"},"quantity":1,"vehicleId":514340}]},"freeDeliveryPeriodDescription":"Free delivery to select locations for trips of 1 week or longer","frequentlyBooked":false,"guestProtectionDisclaimer":"All plans come standard with $2,000,000 liability coverage provided by Economical Insurance Company, or ICBC in British Columbia.","guidelines":"- I will give you the car in good condition. Please return in the same Condition - pretend it's yours!\n\n- No Smoking.\n\n- Enjoy!","highValueVehicle":false,"images":[{"darkModeImageUrl":null,"id":3201265,"originalImageUrl":"https://images.turo.com/media/vehicle/images/WYxYSeQtSSGwNGQYO6iE5g.jpg","placeholder":false,"resizableUrlTemplate":"https://images.turo.com/media/vehicle/images/WYxYSeQtSSGwNGQYO6iE5g.{width}x{height}.jpg","thumbnails":{"170x125":"https://images.turo.com/media/vehicle/images/WYxYSeQtSSGwNGQYO6iE5g.170x102.jpg","170x102":"https://images.turo.com/media/vehicle/images/WYxYSeQtSSGwNGQYO6iE5g.170x102.jpg","620x372":"https://images.turo.com/media/vehicl ...

# %%
import json

# Assuming 'response.json()' is the dictionary you want to dump
data = response.json()

# Serialize the dictionary to a JSON formatted string
json_str = json.dumps(data)

# Calculate the size of the JSON string in bytes
size_in_bytes = len(json_str.encode('utf-8'))

print(f"Size of JSON file in bytes: {size_in_bytes}")
# Out:
# Size of JSON file in bytes: 18771

# %%
import time
import functools

def execution_time_decorator(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()  # Record start time
        result = func(*args, **kwargs)  # Call the actual function
        end_time = time.time()  # Record end time
        execution_time = end_time - start_time  # Calculate elapsed time
        print(f"Execution time of {func.__name__}: {execution_time:.4f} seconds. Args were {args} and kwargs were {kwargs}")
        return result
    return wrapper

# %%
@execution_time_decorator
def get_vehicle_details(vehicleId:int):
    url = f'https://turo.com/api/vehicle/detail?vehicleId={vehicleId}'
    apikey = '43adce71ec56b763f7ab9e710da66c81c448013b'
    params = {
        'url': url,
        'apikey': apikey,
    }
    response = requests.get('https://api.zenrows.com/v1/', params=params)
    return response.json()

# %%
vehicleId = 514340
payload = get_vehicle_details(vehicleId=vehicleId)
# Out:
# Execution time of get_vehicle_details: 4.4794 seconds. Args were () and kwargs were {'vehicleId': 514340}

# %%
cache = {}

for vehicleId in df['id']:

    cache[vehicleId] = get_vehicle_details(vehicleId=vehicleId)
# Out:
# Execution time of get_vehicle_details: 3.6355 seconds. Args were () and kwargs were {'vehicleId': 514340}
# Execution time of get_vehicle_details: 11.2692 seconds. Args were () and kwargs were {'vehicleId': 597559}
# Execution time of get_vehicle_details: 5.1392 seconds. Args were () and kwargs were {'vehicleId': 1109057}
# Execution time of get_vehicle_details: 3.0787 seconds. Args were () and kwargs were {'vehicleId': 1120970}
# Execution time of get_vehicle_details: 3.2698 seconds. Args were () and kwargs were {'vehicleId': 1159994}
# Execution time of get_vehicle_details: 8.3845 seconds. Args were () and kwargs were {'vehicleId': 1174770}
# Execution time of get_vehicle_details: 4.2375 seconds. Args were () and kwargs were {'vehicleId': 1245097}
# Execution time of get_vehicle_details: 12.2806 seconds. Args were () and kwargs were {'vehicleId': 1543514}
# Execution time of get_vehicle_details: 1.8394 seconds. Args were () and kwargs were {'vehicleId': 1546798}
# Execution time of get_vehicle_details: 10.4228 seconds. Args were () and kwargs were {'vehicleId': 1574290}
# Execution time of get_vehicle_details: 3.9676 seconds. Args were () and kwargs were {'vehicleId': 1605462}
# Execution time of get_vehicle_details: 7.0333 seconds. Args were () and kwargs were {'vehicleId': 1625047}
# Execution time of get_vehicle_details: 0.9367 seconds. Args were () and kwargs were {'vehicleId': 1633335}
# Execution time of get_vehicle_details: 2.2164 seconds. Args were () and kwargs were {'vehicleId': 1641639}
# Execution time of get_vehicle_details: 8.2369 seconds. Args were () and kwargs were {'vehicleId': 1653559}
# Execution time of get_vehicle_details: 9.8004 seconds. Args were () and kwargs were {'vehicleId': 1656340}
# Execution time of get_vehicle_details: 0.9173 seconds. Args were () and kwargs were {'vehicleId': 1680452}
# Execution time of get_vehicle_details: 2.4229 seconds. Args were () and kwargs were {'vehicleId': 1711107}
# Execution time of get_vehicle_details: 2.4838 seconds. Args were () and kwargs were {'vehicleId': 1752660}
# Execution time of get_vehicle_details: 0.9622 seconds. Args were () and kwargs were {'vehicleId': 1767321}
# Execution time of get_vehicle_details: 5.7027 seconds. Args were () and kwargs were {'vehicleId': 1770700}
# Execution time of get_vehicle_details: 2.8031 seconds. Args were () and kwargs were {'vehicleId': 1784245}
# Execution time of get_vehicle_details: 2.9151 seconds. Args were () and kwargs were {'vehicleId': 1832182}
# Execution time of get_vehicle_details: 6.9838 seconds. Args were () and kwargs were {'vehicleId': 1851285}
# Execution time of get_vehicle_details: 1.0850 seconds. Args were () and kwargs were {'vehicleId': 1873176}
# Execution time of get_vehicle_details: 1.0041 seconds. Args were () and kwargs were {'vehicleId': 1886474}
# Execution time of get_vehicle_details: 3.9479 seconds. Args were () and kwargs were {'vehicleId': 1919381}
# Execution time of get_vehicle_details: 1.0843 seconds. Args were () and kwargs were {'vehicleId': 1927256}
# Execution time of get_vehicle_details: 3.1328 seconds. Args were () and kwargs were {'vehicleId': 1931956}
# Execution time of get_vehicle_details: 2.2183 seconds. Args were () and kwargs were {'vehicleId': 1954952}
# Execution time of get_vehicle_details: 1.9015 seconds. Args were () and kwargs were {'vehicleId': 1965761}
# Execution time of get_vehicle_details: 1.2176 seconds. Args were () and kwargs were {'vehicleId': 1981881}
# Execution time of get_vehicle_details: 2.6720 seconds. Args were () and kwargs were {'vehicleId': 1989621}
# Execution time of get_vehicle_details: 1.2290 seconds. Args were () and kwargs were {'vehicleId': 1995379}
# Execution time of get_vehicle_details: 0.9344 seconds. Args were () and kwargs were {'vehicleId': 2000120}
# Execution time of get_vehicle_details: 0.7534 seconds. Args were () and kwargs were {'vehicleId': 2027209}
# Execution time of get_vehicle_details: 2.9695 seconds. Args were () and kwargs were {'vehicleId': 2046234}
# Execution time of get_vehicle_details: 3.5466 seconds. Args were () and kwargs were {'vehicleId': 2062582}
# Execution time of get_vehicle_details: 2.8259 seconds. Args were () and kwargs were {'vehicleId': 2066931}
# Execution time of get_vehicle_details: 5.7980 seconds. Args were () and kwargs were {'vehicleId': 2070032}
# Execution time of get_vehicle_details: 4.8445 seconds. Args were () and kwargs were {'vehicleId': 2090418}
# Execution time of get_vehicle_details: 5.5389 seconds. Args were () and kwargs were {'vehicleId': 2094955}
# Execution time of get_vehicle_details: 0.9283 seconds. Args were () and kwargs were {'vehicleId': 2107890}
# Execution time of get_vehicle_details: 5.0399 seconds. Args were () and kwargs were {'vehicleId': 2108462}
# Execution time of get_vehicle_details: 9.2832 seconds. Args were () and kwargs were {'vehicleId': 2114271}
# Execution time of get_vehicle_details: 2.8032 seconds. Args were () and kwargs were {'vehicleId': 2118450}
# Execution time of get_vehicle_details: 9.2391 seconds. Args were () and kwargs were {'vehicleId': 2119221}
# Execution time of get_vehicle_details: 4.7563 seconds. Args were () and kwargs were {'vehicleId': 2123961}
# Execution time of get_vehicle_details: 3.4856 seconds. Args were () and kwargs were {'vehicleId': 2128243}
# Execution time of get_vehicle_details: 5.9511 seconds. Args were () and kwargs were {'vehicleId': 2129153}
# Execution time of get_vehicle_details: 1.3455 seconds. Args were () and kwargs were {'vehicleId': 2147692}
# Execution time of get_vehicle_details: 15.2878 seconds. Args were () and kwargs were {'vehicleId': 2149178}
# Execution time of get_vehicle_details: 4.9310 seconds. Args were () and kwargs were {'vehicleId': 2152530}
# Execution time of get_vehicle_details: 6.1921 seconds. Args were () and kwargs were {'vehicleId': 2165626}
# Execution time of get_vehicle_details: 7.9346 seconds. Args were () and kwargs were {'vehicleId': 2168650}
# Execution time of get_vehicle_details: 1.1670 seconds. Args were () and kwargs were {'vehicleId': 2169905}
# Execution time of get_vehicle_details: 2.6847 seconds. Args were () and kwargs were {'vehicleId': 2171719}
# Execution time of get_vehicle_details: 6.5774 seconds. Args were () and kwargs were {'vehicleId': 2182302}
# Execution time of get_vehicle_details: 6.5110 seconds. Args were () and kwargs were {'vehicleId': 2208681}
# Execution time of get_vehicle_details: 2.9097 seconds. Args were () and kwargs were {'vehicleId': 2215082}
# Execution time of get_vehicle_details: 1.8243 seconds. Args were () and kwargs were {'vehicleId': 2221168}
# Execution time of get_vehicle_details: 4.7662 seconds. Args were () and kwargs were {'vehicleId': 2357054}
# Execution time of get_vehicle_details: 9.7211 seconds. Args were () and kwargs were {'vehicleId': 2391022}
# Execution time of get_vehicle_details: 4.8848 seconds. Args were () and kwargs were {'vehicleId': 2394263}
# Execution time of get_vehicle_details: 6.9054 seconds. Args were () and kwargs were {'vehicleId': 2406506}
# Execution time of get_vehicle_details: 2.1185 seconds. Args were () and kwargs were {'vehicleId': 2426675}
# Execution time of get_vehicle_details: 4.1120 seconds. Args were () and kwargs were {'vehicleId': 2430884}
# Execution time of get_vehicle_details: 7.3473 seconds. Args were () and kwargs were {'vehicleId': 2442227}
# Execution time of get_vehicle_details: 4.8207 seconds. Args were () and kwargs were {'vehicleId': 2446520}
# Execution time of get_vehicle_details: 5.5397 seconds. Args were () and kwargs were {'vehicleId': 2451384}
# Execution time of get_vehicle_details: 1.6351 seconds. Args were () and kwargs were {'vehicleId': 2467725}
# Execution time of get_vehicle_details: 3.8863 seconds. Args were () and kwargs were {'vehicleId': 2478027}
# Execution time of get_vehicle_details: 1.2998 seconds. Args were () and kwargs were {'vehicleId': 2481831}
# Execution time of get_vehicle_details: 1.3188 seconds. Args were () and kwargs were {'vehicleId': 2485849}
# Execution time of get_vehicle_details: 2.0491 seconds. Args were () and kwargs were {'vehicleId': 2488693}
# Execution time of get_vehicle_details: 5.7866 seconds. Args were () and kwargs were {'vehicleId': 2494095}
# Execution time of get_vehicle_details: 8.5967 seconds. Args were () and kwargs were {'vehicleId': 2534862}
# Execution time of get_vehicle_details: 6.9300 seconds. Args were () and kwargs were {'vehicleId': 2537341}
# Execution time of get_vehicle_details: 5.1871 seconds. Args were () and kwargs were {'vehicleId': 2540191}
# Execution time of get_vehicle_details: 5.6644 seconds. Args were () and kwargs were {'vehicleId': 2545525}
# Execution time of get_vehicle_details: 1.5011 seconds. Args were () and kwargs were {'vehicleId': 2563587}
# Execution time of get_vehicle_details: 2.1302 seconds. Args were () and kwargs were {'vehicleId': 2568586}
# Execution time of get_vehicle_details: 4.9416 seconds. Args were () and kwargs were {'vehicleId': 2569700}
# Execution time of get_vehicle_details: 0.8330 seconds. Args were () and kwargs were {'vehicleId': 2577021}
# Execution time of get_vehicle_details: 6.0679 seconds. Args were () and kwargs were {'vehicleId': 2578397}
# Execution time of get_vehicle_details: 1.2831 seconds. Args were () and kwargs were {'vehicleId': 2579662}
# Execution time of get_vehicle_details: 4.9695 seconds. Args were () and kwargs were {'vehicleId': 2579906}
# Execution time of get_vehicle_details: 1.0470 seconds. Args were () and kwargs were {'vehicleId': 2588923}
# Execution time of get_vehicle_details: 5.1043 seconds. Args were () and kwargs were {'vehicleId': 2595828}
# Execution time of get_vehicle_details: 1.4494 seconds. Args were () and kwargs were {'vehicleId': 2596528}
# Execution time of get_vehicle_details: 4.3758 seconds. Args were () and kwargs were {'vehicleId': 2602513}
# Execution time of get_vehicle_details: 2.4447 seconds. Args were () and kwargs were {'vehicleId': 2605673}
# Execution time of get_vehicle_details: 1.9877 seconds. Args were () and kwargs were {'vehicleId': 2609910}
# Execution time of get_vehicle_details: 5.4618 seconds. Args were () and kwargs were {'vehicleId': 2610117}
# Execution time of get_vehicle_details: 2.8527 seconds. Args were () and kwargs were {'vehicleId': 2610827}
# Execution time of get_vehicle_details: 12.8581 seconds. Args were () and kwargs were {'vehicleId': 2617521}
# Execution time of get_vehicle_details: 2.6630 seconds. Args were () and kwargs were {'vehicleId': 2618455}
# Execution time of get_vehicle_details: 3.1346 seconds. Args were () and kwargs were {'vehicleId': 2618874}
# Execution time of get_vehicle_details: 11.7034 seconds. Args were () and kwargs were {'vehicleId': 2620639}
# Execution time of get_vehicle_details: 2.9988 seconds. Args were () and kwargs were {'vehicleId': 2628873}
# Execution time of get_vehicle_details: 5.6559 seconds. Args were () and kwargs were {'vehicleId': 2629540}
# Execution time of get_vehicle_details: 12.4045 seconds. Args were () and kwargs were {'vehicleId': 2631102}
# Execution time of get_vehicle_details: 11.1223 seconds. Args were () and kwargs were {'vehicleId': 2637565}
# Execution time of get_vehicle_details: 6.8625 seconds. Args were () and kwargs were {'vehicleId': 2653518}
# Execution time of get_vehicle_details: 13.3442 seconds. Args were () and kwargs were {'vehicleId': 2669455}
# Execution time of get_vehicle_details: 5.2183 seconds. Args were () and kwargs were {'vehicleId': 2673624}
# Execution time of get_vehicle_details: 9.6363 seconds. Args were () and kwargs were {'vehicleId': 2679860}
# Execution time of get_vehicle_details: 8.4927 seconds. Args were () and kwargs were {'vehicleId': 2683193}
# Execution time of get_vehicle_details: 12.0223 seconds. Args were () and kwargs were {'vehicleId': 2683249}
# Execution time of get_vehicle_details: 8.7766 seconds. Args were () and kwargs were {'vehicleId': 2702212}
# Execution time of get_vehicle_details: 7.4865 seconds. Args were () and kwargs were {'vehicleId': 2702231}
# Execution time of get_vehicle_details: 11.9068 seconds. Args were () and kwargs were {'vehicleId': 2702243}
# Execution time of get_vehicle_details: 7.0372 seconds. Args were () and kwargs were {'vehicleId': 2707772}
# Execution time of get_vehicle_details: 2.6384 seconds. Args were () and kwargs were {'vehicleId': 2712761}
# Execution time of get_vehicle_details: 3.8658 seconds. Args were () and kwargs were {'vehicleId': 2717180}
# Execution time of get_vehicle_details: 1.6449 seconds. Args were () and kwargs were {'vehicleId': 2719149}
# Execution time of get_vehicle_details: 1.4936 seconds. Args were () and kwargs were {'vehicleId': 2719760}
# Execution time of get_vehicle_details: 4.8218 seconds. Args were () and kwargs were {'vehicleId': 2719883}
# Execution time of get_vehicle_details: 3.2000 seconds. Args were () and kwargs were {'vehicleId': 2721823}
# Execution time of get_vehicle_details: 4.5239 seconds. Args were () and kwargs were {'vehicleId': 2721847}
# Execution time of get_vehicle_details: 4.6104 seconds. Args were () and kwargs were {'vehicleId': 2722153}
# Execution time of get_vehicle_details: 11.7167 seconds. Args were () and kwargs were {'vehicleId': 2742443}
# Execution time of get_vehicle_details: 0.8030 seconds. Args were () and kwargs were {'vehicleId': 2747512}
# Execution time of get_vehicle_details: 7.2982 seconds. Args were () and kwargs were {'vehicleId': 2749540}
# Execution time of get_vehicle_details: 1.2990 seconds. Args were () and kwargs were {'vehicleId': 2750579}
# Execution time of get_vehicle_details: 10.3884 seconds. Args were () and kwargs were {'vehicleId': 2751631}
# Execution time of get_vehicle_details: 4.0018 seconds. Args were () and kwargs were {'vehicleId': 2760055}
# Execution time of get_vehicle_details: 0.7913 seconds. Args were () and kwargs were {'vehicleId': 2763931}
# Execution time of get_vehicle_details: 1.5530 seconds. Args were () and kwargs were {'vehicleId': 2770580}
# Execution time of get_vehicle_details: 1.4961 seconds. Args were () and kwargs were {'vehicleId': 2771930}
# Execution time of get_vehicle_details: 4.2017 seconds. Args were () and kwargs were {'vehicleId': 2772635}
# Execution time of get_vehicle_details: 1.0287 seconds. Args were () and kwargs were {'vehicleId': 2775021}
# Execution time of get_vehicle_details: 7.7365 seconds. Args were () and kwargs were {'vehicleId': 2775965}
# Execution time of get_vehicle_details: 3.0187 seconds. Args were () and kwargs were {'vehicleId': 2781783}
# Execution time of get_vehicle_details: 5.3652 seconds. Args were () and kwargs were {'vehicleId': 2782722}
# Execution time of get_vehicle_details: 2.8570 seconds. Args were () and kwargs were {'vehicleId': 2783363}
# Execution time of get_vehicle_details: 3.5107 seconds. Args were () and kwargs were {'vehicleId': 2784568}
# Execution time of get_vehicle_details: 1.3359 seconds. Args were () and kwargs were {'vehicleId': 2784805}
# Execution time of get_vehicle_details: 6.7749 seconds. Args were () and kwargs were {'vehicleId': 2785868}
# Execution time of get_vehicle_details: 4.6590 seconds. Args were () and kwargs were {'vehicleId': 2786226}
# Execution time of get_vehicle_details: 2.3580 seconds. Args were () and kwargs were {'vehicleId': 2787223}
# Execution time of get_vehicle_details: 7.1467 seconds. Args were () and kwargs were {'vehicleId': 2787411}
# Execution time of get_vehicle_details: 7.7531 seconds. Args were () and kwargs were {'vehicleId': 2788317}
# Execution time of get_vehicle_details: 6.9427 seconds. Args were () and kwargs were {'vehicleId': 2791070}
# Execution time of get_vehicle_details: 5.9680 seconds. Args were () and kwargs were {'vehicleId': 2797043}
# Execution time of get_vehicle_details: 0.9043 seconds. Args were () and kwargs were {'vehicleId': 2799459}
# Execution time of get_vehicle_details: 11.5272 seconds. Args were () and kwargs were {'vehicleId': 2808983}
# Execution time of get_vehicle_details: 3.7735 seconds. Args were () and kwargs were {'vehicleId': 2811894}
# Execution time of get_vehicle_details: 1.1159 seconds. Args were () and kwargs were {'vehicleId': 2817863}
# Execution time of get_vehicle_details: 6.1393 seconds. Args were () and kwargs were {'vehicleId': 2818324}
# Execution time of get_vehicle_details: 1.0384 seconds. Args were () and kwargs were {'vehicleId': 2822085}
# Execution time of get_vehicle_details: 3.6735 seconds. Args were () and kwargs were {'vehicleId': 2822397}
# Execution time of get_vehicle_details: 9.5870 seconds. Args were () and kwargs were {'vehicleId': 2827701}
# Execution time of get_vehicle_details: 3.2095 seconds. Args were () and kwargs were {'vehicleId': 2827836}
# Execution time of get_vehicle_details: 6.4057 seconds. Args were () and kwargs were {'vehicleId': 2828412}
# Execution time of get_vehicle_details: 5.5978 seconds. Args were () and kwargs were {'vehicleId': 2828516}
# Execution time of get_vehicle_details: 0.9133 seconds. Args were () and kwargs were {'vehicleId': 2829743}
# Execution time of get_vehicle_details: 8.7707 seconds. Args were () and kwargs were {'vehicleId': 2837265}
# Execution time of get_vehicle_details: 9.6768 seconds. Args were () and kwargs were {'vehicleId': 2837747}
# Execution time of get_vehicle_details: 4.3967 seconds. Args were () and kwargs were {'vehicleId': 2840385}
# Execution time of get_vehicle_details: 8.0957 seconds. Args were () and kwargs were {'vehicleId': 2843889}
# Execution time of get_vehicle_details: 5.4543 seconds. Args were () and kwargs were {'vehicleId': 2844692}
# Execution time of get_vehicle_details: 4.8513 seconds. Args were () and kwargs were {'vehicleId': 2846712}
# Execution time of get_vehicle_details: 6.4332 seconds. Args were () and kwargs were {'vehicleId': 2853254}
# Execution time of get_vehicle_details: 2.5509 seconds. Args were () and kwargs were {'vehicleId': 2854257}
# Execution time of get_vehicle_details: 4.1846 seconds. Args were () and kwargs were {'vehicleId': 2855347}
# Execution time of get_vehicle_details: 2.3191 seconds. Args were () and kwargs were {'vehicleId': 2858233}
# Execution time of get_vehicle_details: 1.5485 seconds. Args were () and kwargs were {'vehicleId': 2860381}
# Execution time of get_vehicle_details: 2.7161 seconds. Args were () and kwargs were {'vehicleId': 2864250}
# Execution time of get_vehicle_details: 6.1882 seconds. Args were () and kwargs were {'vehicleId': 2864305}
# Execution time of get_vehicle_details: 2.1497 seconds. Args were () and kwargs were {'vehicleId': 2866767}
# Execution time of get_vehicle_details: 2.2499 seconds. Args were () and kwargs were {'vehicleId': 2867572}
# Execution time of get_vehicle_details: 10.2401 seconds. Args were () and kwargs were {'vehicleId': 2868377}
# Execution time of get_vehicle_details: 6.8835 seconds. Args were () and kwargs were {'vehicleId': 2869126}
# Execution time of get_vehicle_details: 1.3790 seconds. Args were () and kwargs were {'vehicleId': 2869975}
# Execution time of get_vehicle_details: 6.2144 seconds. Args were () and kwargs were {'vehicleId': 2871945}
# Execution time of get_vehicle_details: 0.9921 seconds. Args were () and kwargs were {'vehicleId': 2872359}
# Execution time of get_vehicle_details: 9.0719 seconds. Args were () and kwargs were {'vehicleId': 2874363}
# Execution time of get_vehicle_details: 8.6982 seconds. Args were () and kwargs were {'vehicleId': 2874448}
# Execution time of get_vehicle_details: 5.3184 seconds. Args were () and kwargs were {'vehicleId': 2878508}
# Execution time of get_vehicle_details: 9.8856 seconds. Args were () and kwargs were {'vehicleId': 2878953}
# Execution time of get_vehicle_details: 5.1209 seconds. Args were () and kwargs were {'vehicleId': 2880142}
# Execution time of get_vehicle_details: 2.7954 seconds. Args were () and kwargs were {'vehicleId': 2881151}
# Execution time of get_vehicle_details: 8.2034 seconds. Args were () and kwargs were {'vehicleId': 2881266}
# Execution time of get_vehicle_details: 2.3231 seconds. Args were () and kwargs were {'vehicleId': 2881500}
# Execution time of get_vehicle_details: 6.5250 seconds. Args were () and kwargs were {'vehicleId': 2882271}
# Execution time of get_vehicle_details: 1.2402 seconds. Args were () and kwargs were {'vehicleId': 2884033}
# Execution time of get_vehicle_details: 3.9335 seconds. Args were () and kwargs were {'vehicleId': 2885215}
# Execution time of get_vehicle_details: 7.2460 seconds. Args were () and kwargs were {'vehicleId': 2886930}
# Execution time of get_vehicle_details: 8.0544 seconds. Args were () and kwargs were {'vehicleId': 2887892}
# Execution time of get_vehicle_details: 8.2399 seconds. Args were () and kwargs were {'vehicleId': 2888301}
# Execution time of get_vehicle_details: 7.4499 seconds. Args were () and kwargs were {'vehicleId': 2892056}
# Execution time of get_vehicle_details: 8.9184 seconds. Args were () and kwargs were {'vehicleId': 2894474}
# Execution time of get_vehicle_details: 1.9538 seconds. Args were () and kwargs were {'vehicleId': 2895005}
# Execution time of get_vehicle_details: 3.3520 seconds. Args were () and kwargs were {'vehicleId': 2895467}
# Execution time of get_vehicle_details: 7.6150 seconds. Args were () and kwargs were {'vehicleId': 2901830}
# Execution time of get_vehicle_details: 5.5815 seconds. Args were () and kwargs were {'vehicleId': 2902077}
# Execution time of get_vehicle_details: 7.3232 seconds. Args were () and kwargs were {'vehicleId': 2902167}
# Execution time of get_vehicle_details: 8.2060 seconds. Args were () and kwargs were {'vehicleId': 2902352}
# Execution time of get_vehicle_details: 8.3169 seconds. Args were () and kwargs were {'vehicleId': 2902649}

# %%
cache[2808983]
# Out:
# {'airportLocations': [],
#  'badges': [{'id': 26, 'label': 'Android Auto', 'value': 'android_auto'},
#   {'id': 25, 'label': 'Apple CarPlay', 'value': 'apple_carplay'},
#   {'id': 27, 'label': 'Backup camera', 'value': 'backup_camera'},
#   {'id': 28, 'label': 'Blind spot warning', 'value': 'blind_spot_warning'},
#   {'id': 17, 'label': 'Bluetooth', 'value': 'bluetooth'},
#   {'id': 4, 'label': 'GPS', 'value': 'gps'},
#   {'id': 23, 'label': 'Heated seats', 'value': 'heated_seats'},
#   {'id': 29, 'label': 'Keyless entry', 'value': 'keyless_entry'},
#   {'id': 24, 'label': 'Sunroof', 'value': 'sunroof'},
#   {'id': 30, 'label': 'USB charger', 'value': 'usb_charger'},
#   {'id': 20, 'label': 'USB input', 'value': 'usb_input'}],
#  'basicCarDetails': {'averageFuelEconomy': None,
#   'averageFuelEconomyWithLabel': None,
#   'cityFuelEconomy': None,
#   'fuelGrade': {'label': 'Regular', 'value': 'REGULAR'},
#   'fuelType': {'label': 'Gas', 'value': 'GASOLINE'},
#   'fuelTypeAndGradeLabel': 'Gas (Regular)',
#   'fuelUnit': 'LITERS_PER_100_KILOMETERS',
#   'fuelUnitLabel': 'L/100km',
#   'highwayFuelEconomy': None,
#   'numberOfDoors': 4,
#   'numberOfDoorsLabel': '4 doors',
#   'numberOfSeats': 5,
#   'numberOfSeatsLabel': '5 seats'},
#  'color': None,
#  'currentVehicleProtection': {'companyInfo': None,
#   'deliveryOwnerFraction': 0.75,
#   'displayName': '75 plan',
#   'hostDeliveryTakeRate': 0.9,
#   'hostTakeRate': 0.75,
#   'insurance': None,
#   'insuranceLicenseNumber': None,
#   'insuranceProviderCaption': None,
#   'insuranceProviderDescription': 'Insurance via Economical',
#   'insuranceProviderDisplayName': 'Economical',
#   'insuranceProviderTitle': 'Insurance & Protection',
#   'label': '75 plan',
#   'location': None,
#   'vehicleProtectionLevel': 'SEVENTYFIVEPLAN_CA_2023',
#   'website': None},
#  'dateRangeRate': None,
#  'description': "Experience the perfect blend of luxury and performance with this Volkswagen Jetta Execline. This premium sedan offers a refined driving experience with its smooth handling, comfortable leather seats, and advanced technology. Enjoy features like a high-resolution touchscreen infotainment system, adaptive cruise control, and a panoramic sunroof. Whether you're commuting or exploring new destinations, the Jetta Execline ensures a stylish and enjoyable ride. Book now for a seamless and sophisticated driving experience.\n\nPlease note that this car has a GPS tracker",
#  'extras': {'extras': [{'description': 'Save time, make drop-off a breeze, and avoid additional fees by adding this Extra, which allows you to return my car at any fuel level. Price includes up to a full tank of gas.',
#     'enabled': True,
#     'extraId': 2281015,
#     'extraPricingType': 'PER_TRIP',
#     'extraType': {'category': {'label': 'Convenience', 'value': 'CONVENIENCE'},
#      'label': 'Prepaid refuel',
#      'maxQuantity': 1,
#      'priceRecommendationSummary': None,
#      'suggestedDescription': None,
#      'value': 'PREPAID_REFUEL'},
#     'priceWithCurrency': {'amount': 80.0, 'currencyCode': 'CAD'},
#     'quantity': 1,
#     'vehicleId': 2808983}]},
#  'freeDeliveryPeriodDescription': None,
#  'frequentlyBooked': False,
#  'guestProtectionDisclaimer': 'All plans come standard with $2,000,000 liability coverage provided by Economical Insurance Company, or ICBC in British Columbia.',
#  'guidelines': None,
#  'highValueVehicle': False,
#  'images': [{'darkModeImageUrl': None,
#    'id': 19303007,
#    'originalImageUrl': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.{width}x{height}.jpg',
#    'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.170x102.jpg',
#     '170x102': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.170x102.jpg',
#     '620x372': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.620x372.jpg',
#     '574x343': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.620x372.jpg',
#     '50x30': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.50x30.jpg',
#     '100x60': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.100x60.jpg'},
#    'verified': False},
#   {'darkModeImageUrl': None,
#    'id': 19303008,
#    'originalImageUrl': 'https://images.turo.com/media/vehicle/images/fPC4BFslReKDS2WGXlkvzw.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/fPC4BFslReKDS2WGXlkvzw.{width}x{height}.jpg',
#    'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/fPC4BFslReKDS2WGXlkvzw.170x102.jpg',
#     '170x102': 'https://images.turo.com/media/vehicle/images/fPC4BFslReKDS2WGXlkvzw.170x102.jpg',
#     '620x372': 'https://images.turo.com/media/vehicle/images/fPC4BFslReKDS2WGXlkvzw.620x372.jpg',
#     '574x343': 'https://images.turo.com/media/vehicle/images/fPC4BFslReKDS2WGXlkvzw.620x372.jpg',
#     '50x30': 'https://images.turo.com/media/vehicle/images/fPC4BFslReKDS2WGXlkvzw.50x30.jpg',
#     '100x60': 'https://images.turo.com/media/vehicle/images/fPC4BFslReKDS2WGXlkvzw.100x60.jpg'},
#    'verified': False},
#   {'darkModeImageUrl': None,
#    'id': 19303004,
#    'originalImageUrl': 'https://images.turo.com/media/vehicle/images/kGprJ_KiQIq6o9fFWW2x2w.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/kGprJ_KiQIq6o9fFWW2x2w.{width}x{height}.jpg',
#    'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/kGprJ_KiQIq6o9fFWW2x2w.170x102.jpg',
#     '170x102': 'https://images.turo.com/media/vehicle/images/kGprJ_KiQIq6o9fFWW2x2w.170x102.jpg',
#     '620x372': 'https://images.turo.com/media/vehicle/images/kGprJ_KiQIq6o9fFWW2x2w.620x372.jpg',
#     '574x343': 'https://images.turo.com/media/vehicle/images/kGprJ_KiQIq6o9fFWW2x2w.620x372.jpg',
#     '50x30': 'https://images.turo.com/media/vehicle/images/kGprJ_KiQIq6o9fFWW2x2w.50x30.jpg',
#     '100x60': 'https://images.turo.com/media/vehicle/images/kGprJ_KiQIq6o9fFWW2x2w.100x60.jpg'},
#    'verified': False},
#   {'darkModeImageUrl': None,
#    'id': 19303005,
#    'originalImageUrl': 'https://images.turo.com/media/vehicle/images/0WpBwm63QI-4jqKanR_KPA.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/0WpBwm63QI-4jqKanR_KPA.{width}x{height}.jpg',
#    'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/0WpBwm63QI-4jqKanR_KPA.170x102.jpg',
#     '170x102': 'https://images.turo.com/media/vehicle/images/0WpBwm63QI-4jqKanR_KPA.170x102.jpg',
#     '620x372': 'https://images.turo.com/media/vehicle/images/0WpBwm63QI-4jqKanR_KPA.620x372.jpg',
#     '574x343': 'https://images.turo.com/media/vehicle/images/0WpBwm63QI-4jqKanR_KPA.620x372.jpg',
#     '50x30': 'https://images.turo.com/media/vehicle/images/0WpBwm63QI-4jqKanR_KPA.50x30.jpg',
#     '100x60': 'https://images.turo.com/media/vehicle/images/0WpBwm63QI-4jqKanR_KPA.100x60.jpg'},
#    'verified': False},
#   {'darkModeImageUrl': None,
#    'id': 19303006,
#    'originalImageUrl': 'https://images.turo.com/media/vehicle/images/E31OkwZMTpKiIbOLwojdng.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/E31OkwZMTpKiIbOLwojdng.{width}x{height}.jpg',
#    'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/E31OkwZMTpKiIbOLwojdng.170x102.jpg',
#     '170x102': 'https://images.turo.com/media/vehicle/images/E31OkwZMTpKiIbOLwojdng.170x102.jpg',
#     '620x372': 'https://images.turo.com/media/vehicle/images/E31OkwZMTpKiIbOLwojdng.620x372.jpg',
#     '574x343': 'https://images.turo.com/media/vehicle/images/E31OkwZMTpKiIbOLwojdng.620x372.jpg',
#     '50x30': 'https://images.turo.com/media/vehicle/images/E31OkwZMTpKiIbOLwojdng.50x30.jpg',
#     '100x60': 'https://images.turo.com/media/vehicle/images/E31OkwZMTpKiIbOLwojdng.100x60.jpg'},
#    'verified': False},
#   {'darkModeImageUrl': None,
#    'id': 19303012,
#    'originalImageUrl': 'https://images.turo.com/media/vehicle/images/HubPDP2oSQ2Q27aoUIW_Rw.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/HubPDP2oSQ2Q27aoUIW_Rw.{width}x{height}.jpg',
#    'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/HubPDP2oSQ2Q27aoUIW_Rw.170x102.jpg',
#     '170x102': 'https://images.turo.com/media/vehicle/images/HubPDP2oSQ2Q27aoUIW_Rw.170x102.jpg',
#     '620x372': 'https://images.turo.com/media/vehicle/images/HubPDP2oSQ2Q27aoUIW_Rw.620x372.jpg',
#     '574x343': 'https://images.turo.com/media/vehicle/images/HubPDP2oSQ2Q27aoUIW_Rw.620x372.jpg',
#     '50x30': 'https://images.turo.com/media/vehicle/images/HubPDP2oSQ2Q27aoUIW_Rw.50x30.jpg',
#     '100x60': 'https://images.turo.com/media/vehicle/images/HubPDP2oSQ2Q27aoUIW_Rw.100x60.jpg'},
#    'verified': False},
#   {'darkModeImageUrl': None,
#    'id': 19303010,
#    'originalImageUrl': 'https://images.turo.com/media/vehicle/images/J6-xSMGYRP23VF_CftNxmg.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/J6-xSMGYRP23VF_CftNxmg.{width}x{height}.jpg',
#    'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/J6-xSMGYRP23VF_CftNxmg.170x102.jpg',
#     '170x102': 'https://images.turo.com/media/vehicle/images/J6-xSMGYRP23VF_CftNxmg.170x102.jpg',
#     '620x372': 'https://images.turo.com/media/vehicle/images/J6-xSMGYRP23VF_CftNxmg.620x372.jpg',
#     '574x343': 'https://images.turo.com/media/vehicle/images/J6-xSMGYRP23VF_CftNxmg.620x372.jpg',
#     '50x30': 'https://images.turo.com/media/vehicle/images/J6-xSMGYRP23VF_CftNxmg.50x30.jpg',
#     '100x60': 'https://images.turo.com/media/vehicle/images/J6-xSMGYRP23VF_CftNxmg.100x60.jpg'},
#    'verified': False},
#   {'darkModeImageUrl': None,
#    'id': 19303009,
#    'originalImageUrl': 'https://images.turo.com/media/vehicle/images/-vS07GpAS9qFFAGs8RilvA.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/-vS07GpAS9qFFAGs8RilvA.{width}x{height}.jpg',
#    'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/-vS07GpAS9qFFAGs8RilvA.170x102.jpg',
#     '170x102': 'https://images.turo.com/media/vehicle/images/-vS07GpAS9qFFAGs8RilvA.170x102.jpg',
#     '620x372': 'https://images.turo.com/media/vehicle/images/-vS07GpAS9qFFAGs8RilvA.620x372.jpg',
#     '574x343': 'https://images.turo.com/media/vehicle/images/-vS07GpAS9qFFAGs8RilvA.620x372.jpg',
#     '50x30': 'https://images.turo.com/media/vehicle/images/-vS07GpAS9qFFAGs8RilvA.50x30.jpg',
#     '100x60': 'https://images.turo.com/media/vehicle/images/-vS07GpAS9qFFAGs8RilvA.100x60.jpg'},
#    'verified': False}],
#  'inNeedOfAirportMigration': False,
#  'inspectionDetails': None,
#  'instantBookLocationPreferences': {'airportLocationEnabled': False,
#   'customLocationEnabled': False,
#   'homeLocationEnabled': True,
#   'poiLocationEnabled': False},
#  'listingDeleted': False,
#  'listingEnabled': True,
#  'location': {'address': 'Montréal, QC H2L 0J6',
#   'addressLines': ['Montréal, QC'],
#   'city': 'Montréal',
#   'country': 'CA',
#   'id': 30293813,
#   'latitude': 45.51764874045079,
#   'locationSource': 'GOOGLE',
#   'longitude': -73.55423534968008,
#   'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#   'state': 'QC',
#   'timeZone': 'America/Toronto'},
#  'minimumAgeInYearsToRent': None,
#  'numberOfFaqs': 0,
#  'numberOfFavorites': 38,
#  'numberOfRentals': 12,
#  'numberOfReviews': 11,
#  'owner': {'allStarHost': True,
#   'firstName': 'Aziz Yamar',
#   'id': 15417200,
#   'image': {'darkModeImageUrl': None,
#    'id': None,
#    'originalImageUrl': 'https://images.turo.com/media/driver/yuKeYtdNT8m1XeWsWXwnHg.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/driver/yuKeYtdNT8m1XeWsWXwnHg.{width}x{height}.jpg',
#    'thumbnails': {'84x84': 'https://images.turo.com/media/driver/yuKeYtdNT8m1XeWsWXwnHg.84x84.jpg',
#     '300x300': 'https://images.turo.com/media/driver/yuKeYtdNT8m1XeWsWXwnHg.300x300.jpg',
#     '225x225': 'https://images.turo.com/media/driver/yuKeYtdNT8m1XeWsWXwnHg.300x300.jpg',
#     '32x32': 'https://images.turo.com/media/driver/yuKeYtdNT8m1XeWsWXwnHg.32x32.jpg'},
#    'verified': False},
#   'lastName': 'G.',
#   'name': 'Aziz Yamar G.',
#   'proHost': False,
#   'url': 'https://turo.com/us/en/drivers/15417200'},
#  'parkingDetails': None,
#  'rate': {'airportDeliveryFee': None,
#   'airportDeliveryLocationsAndFees': [],
#   'averageDailyPrice': 118.75,
#   'averageDailyPriceWithCurrency': {'amount': 118.75, 'currencyCode': 'CAD'},
#   'customDeliveryDistance': None,
#   'customDeliveryFee': None,
#   'daily': 118.75,
#   'dailyDistance': {'scalar': 300, 'unit': 'KM', 'unlimited': False},
#   'dailyMileage': 300,
#   'excessFeePerDistance': None,
#   'homeLocationFee': 'Free',
#   'monthlyDiscountPercentage': 60,
#   'monthlyDistance': {'scalar': 2700, 'unit': 'KM', 'unlimited': False},
#   'monthlyMileage': 2700,
#   'promotionResponse': None,
#   'regularAirportDeliveryFee': None,
#   'regularCustomDeliveryFee': None,
#   'weeklyDiscountPercentage': 10,
#   'weeklyDistance': {'scalar': 2100, 'unit': 'KM', 'unlimited': False},
#   'weeklyMileage': 2100},
#  'ratings': {'histogram': {'buckets': [{'averageRating': 5.0,
#      'category': 'CLEANLINESS',
#      'label': 'Cleanliness'},
#     {'averageRating': 5.0, 'category': 'MAINTENANCE', 'label': 'Maintenance'},
#     {'averageRating': 5.0,
#      'category': 'COMMUNICATION',
#      'label': 'Communication'},
#     {'averageRating': 5.0, 'category': 'CONVENIENCE', 'label': 'Convenience'},
#     {'averageRating': 5.0,
#      'category': 'LISTING_ACCURACY',
#      'label': 'Accuracy'}],
#    'ratingsCount': 10},
#   'ownerOverall': 5,
#   'ratingToHundredth': 5.0,
#   'vehicleId': 2808983},
#  'tieredOwnerProtectionEnabled': True,
#  'tripCount': 12,
#  'turoGo': False,
#  'turoGoExplanation': None,
#  'vehicle': {'automaticTransmission': True,
#   'id': 2808983,
#   'image': {'darkModeImageUrl': None,
#    'id': 19303007,
#    'originalImageUrl': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.jpg',
#    'placeholder': False,
#    'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.{width}x{height}.jpg',
#    'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.170x102.jpg',
#     '170x102': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.170x102.jpg',
#     '620x372': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.620x372.jpg',
#     '574x343': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.620x372.jpg',
#     '50x30': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.50x30.jpg',
#     '100x60': 'https://images.turo.com/media/vehicle/images/327piDQERDuG2edZbBmyhA.100x60.jpg'},
#    'verified': False},
#   'listingCreatedTime': 1722996367000,
#   'make': 'Volkswagen',
#   'marketAreaId': None,
#   'marketCountry': 'CA',
#   'model': 'Jetta',
#   'name': "Aziz Yamar's Volkswagen",
#   'registration': {'insuranceCardUrl': 'https://help.turo.com/SJJELVe4c',
#    'licensePlate': None,
#    'regionRequired': True,
#    'state': 'QC'},
#   'trim': 'Execline',
#   'type': 'CAR',
#   'url': 'https://turo.com/us/en/car-rental/canada/montreal-qc/volkswagen/jetta/2808983',
#   'vin': None,
#   'year': 2019,
#   'marketCurrency': {'currencyCode': 'CAD',
#    'decimalPlaces': 2,
#    'defaultFractionDigits': 2,
#    'symbol': 'CAD'}},
#  'vehicleDeliveryLocations': [],
#  'vehicleStatus': 'ACTIVE',
#  'vehicleValueType': {'explanation': {'details': [],
#    'subtitle': None,
#    'title': None},
#   'subtitle': None,
#   'title': None,
#   'type': 'STANDARD'}}

# %%
with open("../data/vehicle_details.json", "w") as fp:
    json.dump(cache, fp)

# %% [markdown]
# ## Automting extraction flow for daily_pricing

# %% [markdown]
# ## DEBUG
